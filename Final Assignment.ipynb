# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **André Gouveia**<br>
# Supervisory officer

# %% [markdown]
# *I am interested in data science because I want to add to my skills and find a new job, and I like drawing insights from data*

# %% [markdown]
# ### My code prints even numbers between 1 and 10

# %%
numb = range (1,10)

even = []

for i in numb:
    if i%2 == 0:
        even.append (i)

print (even)
# Out:
# [2, 4, 6, 8]

# %% [markdown]
# 1. One
# 2. Two
# 3. Three
#
# ***
#
# | Items | Present |
# | --------- |------|
# |Horizontal rule | Yes |
# |Bulleted List| No|
# | Numbered List| Yes|
# |Table| Yes|
# |Hyperlink| Yes|
# |Image | Yes|
# |Highlighting| No|
# |Blocked quotes| No|
# |Strikethrough| No|
#
# Our website can be found at <a href="url" target="_blank">www.cmvm.pt
#
# ![logo CMVM](https://www.cmvm.pt/Style%20Library/cmvm/img/cmvm_logo_v2.png)
